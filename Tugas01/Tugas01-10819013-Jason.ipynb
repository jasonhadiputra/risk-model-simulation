# %% [markdown]
# # 1

# %%
from scipy import stats
SEED = 42

sample = stats.norm.rvs(loc=245.7, scale=13.5, size=100, random_state=SEED)
sample
# Out:
# array([252.40564107, 243.83343193, 254.44379526, 266.26090306,
#        242.53892944, 242.53915108, 267.01937301, 256.06036884,
#        239.36209579, 253.02456059, 239.44386115, 239.41264833,
#        248.96649067, 219.8707167 , 222.41360926, 238.10911836,
#        232.02677988, 249.94233899, 233.44167498, 226.63390003,
#        265.48625838, 242.65201994, 246.61163076, 226.46589949,
#        238.35083322, 247.19745496, 230.1615867 , 250.77192325,
#        237.59137769, 241.76213438, 237.57696073, 270.70575549,
#        245.51778747, 231.42090246, 256.80435631, 229.21861073,
#        248.51965853, 219.24445333, 227.76948834, 248.35762668,
#        255.66929883, 248.0134718 , 244.13874819, 241.63510011,
#        225.73995313, 235.98210319, 239.48137659, 259.97115005,
#        250.33884691, 221.8989579 , 250.07513359, 240.50138921,
#        236.561553  , 253.9576299 , 259.61849355, 258.27228161,
#        234.37056344, 241.52563293, 250.17205632, 258.86985922,
# ...

# %% [markdown]
# # 2

# %%
from statsmodels.sandbox.stats.runs import runstest_1samp

runstest_1samp(sample, cutoff='median', correction=True)
# Out:
# (0.201017818278147, 0.8406846414712399)

# %% [markdown]
# # 3

# %%
sample.mean()
# Out:
# 244.2980720151797

# %%
sample.std()
